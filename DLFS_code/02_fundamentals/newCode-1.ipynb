# %%
import numpy as np
from numpy import ndarray

from typing import Callable, Dict, Tuple, List

np.set_printoptions(precision=4)
# GRAPHS_IMG_FILEPATH = "/Users/seth/development/01_deep-learning-from-scratch/images/02_fundamentals/graphs/"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
TEST_ALL = False

# %% [markdown]
# # Boston data
# 这段代码使用了 scikit-learn 库，一个在 Python 中非常受欢迎的机器学习库。
# 具体来说，代码是加载并使用了 load_boston 函数，该函数返回波士顿房价数据集
# 。这是一个用于回归任务的经典数据集。

# %%
# from sklearn.datasets import load_boston

# %%
# boston = load_boston()

# %%
# boston[0]

# %%
import pandas as pd
import numpy as np

# 从原始来源获取数据
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# 以下是 Boston 房价数据集的特征名称，与原始 load_boston 返回的接口相匹配
features = np.array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

# %% [markdown]
# # SciKit Learn Linear Regression

# %% [markdown]
# ## Data prep

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
data = s.fit_transform(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=80718)

y_train, y_test = y_train.reshape(-1, 1), y_test.reshape(-1, 1)

# %% [markdown]
# ## Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept=True)
lr.fit(X_train, y_train)
preds = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.title("Predicted vs. Actual values for\nnLinear Regression model")
plt.xlim([0, 51])
plt.ylim([0, 51])
plt.scatter(preds, y_test)
plt.plot([0, 51], [0, 51]);
# plt.savefig(IMG_FILEPATH + "00_linear_real_pred_vs_actual.png");

# %% [markdown]
# ## Testing changing feature

# %%
plt.scatter(X_test[:, 12], y_test)
plt.xlabel("Most important feature from our data")
plt.ylabel("Target")
plt.title("Relationship between most\nimportant feature and target");
# plt.savefig(IMG_FILEPATH + "02_most_important_feature_vs_target.png")

# %% [markdown]
# Non linear relationship

# %% [markdown]
# ## Model error

# %%
def mae(preds: ndarray, actuals: ndarray):
    '''
    Compute mean absolute error.
    '''
    return np.mean(np.abs(preds - actuals))

def rmse(preds: ndarray, actuals: ndarray):
    '''
    Compute root mean squared error.
    '''
    return np.sqrt(np.mean(np.power(preds - actuals, 2)))

# %%
print("Mean absolute error:", round(mae(preds, y_test), 4), "\n"
      "Root mean squared error:", round(rmse(preds, y_test), 4))
# Out:
# Mean absolute error: 3.5671
# Root mean squared error: 5.0476

# %%
# 在这里，lr.coef_ 是从训练好的线性回归模型 lr 中获取的系数（也称为权重或参数）。
# 这些系数描述了每一个特征对预测值的影响程度。
# 具体地说，它们表示当一个特征的值增加 1 个单位时，目标变量（在这个例子中是房价）预期会增加或减少多少。
import numpy as np
np.round(lr.coef_, 2)
# Out:
# array([[-1.01,  0.71,  0.28,  0.71, -2.21,  2.38,  0.71, -2.66,  2.63,
#         -1.82, -2.33,  0.85, -4.19]])

# %% [markdown]
# ## Manual linear regression

# %%
def forward_linear_regression(X_batch: ndarray,
                              y_batch: ndarray,
                              weights: Dict[str, ndarray]
                              )-> Tuple[float, Dict[str, ndarray]]:
    '''
    Forward pass for the step-by-step linear regression.
    '''
    # assert batch sizes of X and y are equal
    assert X_batch.shape[0] == y_batch.shape[0]

    # assert that matrix multiplication can work
    assert X_batch.shape[1] == weights['W'].shape[0]

    # assert that B is simply a 1x1 ndarray
    assert weights['B'].shape[0] == weights['B'].shape[1] == 1

    # compute the operations on the forward pass
    N = np.dot(X_batch, weights['W'])

    P = N + weights['B']

    loss = np.mean(np.power(y_batch - P, 2))

    # save the information computed on the forward pass
    forward_info: Dict[str, ndarray] = {}
    forward_info['X'] = X_batch
    forward_info['N'] = N
    forward_info['P'] = P
    forward_info['y'] = y_batch

    return loss, forward_info

# %%
def to_2d_np(a: ndarray, 
             type: str = "col") -> ndarray:
    '''
    Turns a 1D Tensor into 2D
    '''

    assert a.ndim == 1, \
    "Input tensors must be 1 dimensional"
    
    if type == "col":        
        return a.reshape(-1, 1)
    elif type == "row":
        return a.reshape(1, -1)

# %%
# 这个函数的目的是为了重新排列或混洗数据集。这在机器学习的训练过程中是一个常见的步骤，尤其是在每个训练周期开始时。
# 重新排列数据有助于确保模型不会记住或过度适应特定的数据顺序，这可以帮助模型在不同的数据上都表现良好。
def permute_data(X: ndarray, y: ndarray):
    '''
    Permute X and y, using the same permutation, along axis=0
    '''
    perm = np.random.permutation(X.shape[0])
    return X[perm], y[perm]

# %%
def loss_gradients(forward_info: Dict[str, ndarray],
                   weights: Dict[str, ndarray]) -> Dict[str, ndarray]:
    '''
    Compute dLdW and dLdB for the step-by-step linear regression model.
    '''
    batch_size = forward_info['X'].shape[0]
    # dLdP 平方误差求导，计算真实值与预测值之间的差值，再乘以-2，得到损失对预测值的梯度
    dLdP = -2 * (forward_info['y'] - forward_info['P'])
    # 预测 P 是通过加权和 N 加上偏置 B 得到的。因此，相对于 N 的梯度是1，而相对于 B 的梯度也是1。
    dPdN = np.ones_like(forward_info['N'])
    dPdB = np.ones_like(weights['B'])
    # 通过链式法则，计算损失对N的梯度
    dLdN = dLdP * dPdN
    # 得到损失对权重W的梯度
    dNdW = np.transpose(forward_info['X'], (1, 0))
    
    # need to use matrix multiplication here,
    # with dNdW on the left (see note at the end of last chapter)  
    # 利用矩阵乘法计算损失对权重W的梯度
    dLdW = np.dot(dNdW, dLdN)

    # need to sum along dimension representing the batch size:
    # see note near the end of the chapter
    # 计算损失对偏置B的梯度。因为偏置对所有样本都是相同的，所以在这里我们要对所有样本求和
    dLdB = (dLdP * dPdB).sum(axis=0)
    # 将计算出的梯度保存在一个字典中并返回
    loss_gradients: Dict[str, ndarray] = {}
    loss_gradients['W'] = dLdW
    loss_gradients['B'] = dLdB

    return loss_gradients

# %%
Batch = Tuple[ndarray, ndarray]

def generate_batch(X: ndarray, 
                   y: ndarray,
                   start: int = 0,
                   batch_size: int = 10) -> Batch:
    '''
    Generate batch from X and y, given a start position
    '''
    assert X.ndim == y.ndim == 2, \
    "X and Y must be 2 dimensional"

    if start+batch_size > X.shape[0]:
        batch_size = X.shape[0] - start
    
    X_batch, y_batch = X[start:start+batch_size], y[start:start+batch_size]
    
    return X_batch, y_batch

# %%
def forward_loss(X: ndarray,
                 y: ndarray,
                 weights: Dict[str, ndarray]) -> Tuple[Dict[str, ndarray], float]:
    '''
    Generate predictions and calculate loss for a step-by-step linear regression
    (used mostly during inference).
    '''
    # 计算X（数据）与权重W的矩阵乘法，结果为N。
    # 这一步实际上是对每个特征的权重进行线性组合。
    N = np.dot(X, weights['W'])

    # 在N的基础上加上偏置B（bias），得到预测值P。
    P = N + weights['B']

    # 计算真实值y与预测值P之间的均方误差。
    loss = np.mean(np.power(y - P, 2))

    # 将在前向传播过程中计算的中间值保存在一个字典中。
    # 这些中间值在后续的反向传播计算中可能会用到。
    forward_info: Dict[str, ndarray] = {}
    forward_info['X'] = X  # 输入数据
    forward_info['N'] = N  # X与W的乘积结果
    forward_info['P'] = P  # 最终的预测值
    forward_info['y'] = y  # 真实值

    return forward_info, loss

# %%
def init_weights(n_in: int) -> Dict[str, ndarray]:
    '''
    Initialize weights on first forward pass of model.
    '''
    
    weights: Dict[str, ndarray] = {}
    # 随机生成系数
    W = np.random.randn(n_in, 1)
    # 随机生成偏置
    B = np.random.randn(1, 1)
    
    weights['W'] = W
    weights['B'] = B

    return weights

# %%
def train(X: ndarray,   # 输入数据
          y: ndarray,   # 目标值
          n_iter: int = 1000, # 迭代次数或称为训练周期
          learning_rate: float = 0.01, # 学习率，决定参数更新的步长。
          batch_size: int = 100,  # 在每次迭代中使用的数据点数量
          return_losses: bool = False,  # 是否返回每次迭代的损失值。
          return_weights: bool = False, # 是否返回训练后的权重。
          seed: int = 1) -> None:  # 用于随机数生成的种子值
    '''
    Train model for a certain number of epochs.
    '''
    if seed:
        np.random.seed(seed)
    
    # 初始化起始索引为0
    start = 0

    # 对于一个形状为(m, n)的二维数组（也可以看作是m行n列的矩阵）。X.shape[1]返回该二维数组的列数（第二个维度的大小），即n。来初始化权重和偏置
    weights = init_weights(X.shape[1])

    # 将数据X和y打乱
    X, y = permute_data(X, y)

    # 如果需要返回损失，就初始化一个空的损失列表
    if return_losses:
        losses = []
        
    # 开始训练，进行n_iter次迭代
    for i in range(n_iter):

        # 如果起始索引超出了数据的大小，重新打乱数据并将起始索引重置为0
        if start >= X.shape[0]:
            X, y = permute_data(X, y)
            start = 0

        # 从当前起始索引开始，获取一个数据批次
        X_batch, y_batch = generate_batch(X, y, start, batch_size)
        start += batch_size
    
        # Train net using generated batch
        # 对当前批次进行前向传播并计算损失
        forward_info, loss = forward_loss(X_batch, y_batch, weights)

        if return_losses:
            losses.append(loss)

         # 使用梯度来更新权重
        loss_grads = loss_gradients(forward_info, weights)
        for key in weights.keys():
            weights[key] -= learning_rate * loss_grads[key]

    if return_weights:
        return losses, weights
    
    return None

# %%
train_info = train(X_train, y_train,
                   n_iter = 1000,
                   learning_rate = 0.001,
                   batch_size=23, 
                   return_losses=True, 
                   return_weights=True, 
                   seed=180708)
losses = train_info[0]
weights = train_info[1]

# %%
plt.plot(list(range(1000)), losses);

# %%
def predict(X: ndarray,
            weights: Dict[str, ndarray]):
    '''
    Generate predictions from the step-by-step linear regression model.
    '''

    N = np.dot(X, weights['W'])

    return N + weights['B']

# %%
preds = predict(X_test, weights)

# %%
print("Mean absolute error:", round(mae(preds, y_test), 4), "\n"
      "Root mean squared error:", round(rmse(preds, y_test), 4))
# Out:
# Mean absolute error: 3.5644
# Root mean squared error: 5.0497

# %%
np.round(y_test.mean(), 4)
# Out:
# 22.0776

# %%
np.round(rmse(preds, y_test) / y_test.mean(), 4)
# Out:
# 0.2287

# %% [markdown]
# RMSE is 23% on average of y.

# %%
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.title("Predicted vs. Actual values for\ncustom linear regression model");
plt.xlim([0, 51])
plt.ylim([0, 51])
plt.scatter(preds, y_test)
plt.plot([0, 51], [0, 51]);
# plt.savefig(GRAPHS_IMG_FILEPATH + "01_linear_custom_pred_vs_actual.png");

# %%
NUM = 40

# 从X_test中取除最后一列外的所有列。 计算这些列的均值。这里axis=0意味着沿着行方向进行计算，所以计算的是每一列的均值。
a = np.repeat(X_test[:,:-1].mean(axis=0, keepdims=True), NUM, axis=0)

# 在-1.5和3.5之间均匀地生成NUM个数字。
b = np.linspace(-1.5, 3.5, NUM).reshape(NUM, 1)
# 将a和b两个数组沿着列方向拼接，形成新的test_feature数组。
test_feature = np.concatenate([a, b], axis=1)

# 对test_feature进行预测。然后从预测的结果中取第一列的值（假设预测的输出是一个二维数组）。
test_preds = predict(test_feature, weights)[:, 0]

# %%
plt.scatter(X_test[:, 12], y_test)
plt.plot(np.array(test_feature[:, -1]), test_preds, linewidth=2, c='orange')
plt.ylim([6, 51])
plt.xlabel("Most important feature (normalized)")
plt.ylabel("Target/Predictions")
plt.title("Most important feature vs. target and predictions,\n custom linear regression");
# plt.savefig(GRAPHS_IMG_FILEPATH + "03_most_important_feature_vs_predictions.png")

# %% [markdown]
# ## Coefficients

# %%
np.round(weights['W'].reshape(-1), 4)
# Out:
# array([-1.0954,  0.7353,  0.1977,  0.7475, -2.2849,  2.2006,  0.7195,
#        -2.6384,  2.5358, -1.6892, -2.3162,  0.8435, -4.2553])

# %%
np.round(lr.coef_, 4)
# Out:
# array([[-1.0148,  0.7065,  0.276 ,  0.7092, -2.206 ,  2.3793,  0.7133,
#         -2.6625,  2.6325, -1.8172, -2.3266,  0.8465, -4.1889]])

# %%
np.round(weights['B'], 4)
# Out:
# array([[22.6312]])

# %%
np.round(lr.intercept_, 4)
# Out:
# array([22.6195])

# %% [markdown]
# Coefficients are the same in the SciKit Learn linear regression as in the "custom" linear regression.

# %% [markdown]
# ## Theoretical relationship between most important feature and target
# 我们只能够模拟一种线性的关系

# %%
NUM = 40
a = np.repeat(X_test[:,:-1].mean(axis=0, keepdims=True), NUM, axis=0)
b = np.linspace(-1.5, 3.5, NUM).reshape(NUM, 1)

# %%
test_feature = np.concatenate([a, b], axis=1)
preds = predict(test_feature, weights)[:, 0]

# %%
plt.scatter(np.array(test_feature[:, -1]), np.array(preds))
plt.ylim([6, 51])
# plt.savefig(GRAPHS_IMG_FILEPATH + "/04_relationship_most_impt_feat_preds.png")
# Out:
# (6.0, 51.0)

# %% [markdown]
# # Neural network regression

# %%
def sigmoid(x: ndarray) -> ndarray:
    return 1 / (1 + np.exp(-1.0 * x))

# %%
plt.plot(np.arange(-5, 5, 0.01),
         sigmoid(np.arange(-5, 5, 0.01)));
plt.title("Sigmoid function plotted from x=-5 to x=5")
plt.xlabel("X")
plt.ylabel("$sigmoid(x)$");
# plt.savefig(GRAPHS_IMG_FILEPATH + "05_sigmoid_function.png")

# %%
def init_weights(input_size: int, 
                 hidden_size: int) -> Dict[str, ndarray]:
    '''
    Initialize weights during the forward pass for step-by-step neural network model.
    '''
    weights: Dict[str, ndarray] = {}
    weights['W1'] = np.random.randn(input_size, hidden_size)
    weights['B1'] = np.random.randn(1, hidden_size)
    weights['W2'] = np.random.randn(hidden_size, 1)
    weights['B2'] = np.random.randn(1, 1)
    return weights

# %% [markdown]
# \begin{align*}
# M_1 & = X \cdot W_1 \\
# N_1 & = M_1 + B_1 \\
# O_1 & = \sigma(N_1) \\
# M_2 & = O_1 \cdot W_2 \\
# P & = M_2 + B_2 \\
# \text{loss} & = \frac{1}{N} \sum_{i=1}^{N} (y_i - P_i)^2
# \end{align*}

# %% [markdown]
# $$ P = \sigma(X \cdot W_1 + B_1) \cdot W_2 + B_2 $$

# %%
def forward_loss(X: ndarray,
                 y: ndarray,
                 weights: Dict[str, ndarray]
                 ) -> Tuple[Dict[str, ndarray], float]:
    '''
    Compute the forward pass and the loss for the step-by-step 
    neural network model.     
    '''
    M1 = np.dot(X, weights['W1'])

    N1 = M1 + weights['B1']

    O1 = sigmoid(N1)
    
    M2 = np.dot(O1, weights['W2'])

    P = M2 + weights['B2']    

    loss = np.mean(np.power(y - P, 2))

    forward_info: Dict[str, ndarray] = {}
    forward_info['X'] = X
    forward_info['M1'] = M1
    forward_info['N1'] = N1
    forward_info['O1'] = O1
    forward_info['M2'] = M2
    forward_info['P'] = P
    forward_info['y'] = y

    return forward_info, loss

# %%
def loss_gradients(forward_info: Dict[str, ndarray], 
                   weights: Dict[str, ndarray]) -> Dict[str, ndarray]:
    '''
    Compute the partial derivatives of the loss with respect to each of the parameters in the neural network.
    '''    
    # 计算损失相对于输出的梯度:
    dLdP = -2*(forward_info['y'] - forward_info['P'])
    # 计算输出相对于第二层加权和的梯度:
    dPdM2 = np.ones_like(forward_info['M2'])
    # 计算损失相对于第二层加权和的梯度
    dLdM2 = dLdP * dPdM2
    # 计算损失相对于第二层偏置的梯度:  
    dPdB2 = np.ones_like(weights['B2'])
    dLdB2 = (dLdP * dPdB2).sum(axis=0)
    # 计算损失相对于第二层权重的梯度，他是第一层输出的偏置
    dM2dW2 = np.transpose(forward_info['O1'], (1, 0))
    dLdW2 = np.dot(dM2dW2, dLdP)
    # 计算损失相对于隐藏层输出的梯度:
    dM2dO1 = np.transpose(weights['W2'], (1, 0)) 
    dLdO1 = np.dot(dLdM2, dM2dO1)
    # 计算隐藏层输出相对于隐藏层加权和的梯度，使用sigmoid激活函数的导数公式。
    dO1dN1 = sigmoid(forward_info['N1']) * (1- sigmoid(forward_info['N1']))
    dLdN1 = dLdO1 * dO1dN1
    # 为第一层的偏置B1计算梯度:
    dN1dB1 = np.ones_like(weights['B1'])
    dLdB1 = (dLdN1 * dN1dB1).sum(axis=0)
    # 计算损失相对于第一层的加权和M1的梯度
    dN1dM1 = np.ones_like(forward_info['M1'])
    dLdM1 = dLdN1 * dN1dM1
    # 为第一层的权重W1计算梯度。这需要考虑到输入X，因为它是第一层权重的输入
    dM1dW1 = np.transpose(forward_info['X'], (1, 0)) 

    dLdW1 = np.dot(dM1dW1, dLdM1)

    loss_gradients: Dict[str, ndarray] = {}
    loss_gradients['W2'] = dLdW2
    loss_gradients['B2'] = dLdB2.sum(axis=0)
    loss_gradients['W1'] = dLdW1
    loss_gradients['B1'] = dLdB1.sum(axis=0)
    
    return loss_gradients

# %%
def predict(X: ndarray, 
            weights: Dict[str, ndarray]) -> ndarray:
    '''
    Generate predictions from the step-by-step neural network model. 
    '''
    M1 = np.dot(X, weights['W1'])

    N1 = M1 + weights['B1']

    O1 = sigmoid(N1)

    M2 = np.dot(O1, weights['W2'])

    P = M2 + weights['B2']    

    return P

# %%
def train(X_train: ndarray, y_train: ndarray,
          X_test: ndarray, y_test: ndarray,
          n_iter: int = 1000,
          test_every: int = 1000,
          learning_rate: float = 0.01,
          hidden_size= 13,
          batch_size: int = 100,
          return_losses: bool = False, 
          return_weights: bool = False, 
          return_scores: bool = False,
          seed: int = 1) -> None:

    if seed:
        np.random.seed(seed)

    start = 0

    # Initialize weights
    weights = init_weights(X_train.shape[1], 
                           hidden_size=hidden_size)

    # Permute data
    X_train, y_train = permute_data(X_train, y_train)
    

    losses = []
        
    val_scores = []

    for i in range(n_iter):

        # Generate batch
        if start >= X_train.shape[0]:
            X_train, y_train = permute_data(X_train, y_train)
            start = 0
        
        X_batch, y_batch = generate_batch(X_train, y_train, start, batch_size)
        start += batch_size
    
        # Train net using generated batch
        forward_info, loss = forward_loss(X_batch, y_batch, weights)

        if return_losses:
            losses.append(loss)

        loss_grads = loss_gradients(forward_info, weights)
        for key in weights.keys():
            weights[key] -= learning_rate * loss_grads[key]
        
        if return_scores:
            if i % test_every == 0 and i != 0:
                preds = predict(X_test, weights)
                val_scores.append(r2_score(preds, y_test))

    if return_weights:
        return losses, weights, val_scores
    
    return None

# %%
if TEST_ALL:
    num_iter = 10000
    test_every = 1000
    train_info = train(X_train, y_train, X_test, y_test,
                       n_iter=num_iter,
                       test_every = test_every,
                       learning_rate = 0.001,
                       batch_size=23, 
                       return_losses=False, 
                       return_weights=True, 
                       return_scores=False,
                       seed=80718)
    losses = train_info[0]
    weights = train_info[1]
    val_scores = train_info[2]

# %%
if TEST_ALL:
    import matplotlib.pyplot as plt
    # %matplotlib inline
    plt.ylim([-1,1])
    plt.plot(list(range(int(num_iter / test_every - 1))), val_scores); 
    plt.xlabel("Batches (000s)")
    plt.title("Validation Scores")

# %% [markdown]
# ### Learning rate tuning

# %%
def r2_score_lr(learning_rate):
    train_info = train(X_train, y_train, X_test, y_test,
                   n_iter=100000,
                   test_every = 100000,
                   learning_rate = learning_rate,
                   batch_size=23, 
                   return_losses=False, 
                   return_weights=True, 
                   return_scores=False,
                   seed=80718)
    weights = train_info[1]
    preds = predict(X_test, weights)
    return r2_score(y_test, preds)

# %%
if TEST_ALL:
    lrs = np.geomspace(1e-2, 1e-6, num=20)

# %%
if TEST_ALL:
    r2s = [r2_score_lr(lr) for lr in lrs]

# %%
if TEST_ALL:
    plt.semilogx(lrs, r2s)

# %% [markdown]
# ## Evaluating best model

# %%
train_info = train(X_train, y_train, X_test, y_test,
                   n_iter=10000,
                   test_every = 1000,
                   learning_rate = 0.001,
                   batch_size=23, 
                   return_losses=True, 
                   return_weights=True, 
                   return_scores=False,
                   seed=180807)
losses = train_info[0]
weights = train_info[1]

# %%
plt.plot(list(range(10000)), losses);

# %%
preds = predict(X_test, weights)

# %% [markdown]
# ## Investigation of most important features

# %% [markdown]
# Most important combinations of features are the two with absolute values of greater than 9:

# %%
weights['W2']
# Out:
# array([[  6.863 ],
#        [  8.688 ],
#        [  6.4594],
#        [  5.923 ],
#        [  7.4641],
#        [  7.112 ],
#        [  4.8172],
#        [ 10.2882],
#        [  6.424 ],
#        [-10.4506],
#        [  8.2089],
#        [  5.2493],
#        [ -5.2892]])

# %% [markdown]
# These are at index 7 and index 9. Here are the combinations themselves:

# %%
weights['W1'][7]
# Out:
# array([-1.9269,  0.2724,  0.1792, -1.447 ,  1.4714, -3.6308, -2.3507,
#        -0.3166,  0.5202,  1.2347,  0.0403, -0.9014,  0.6544])

# %%
weights['W1'][9]
# Out:
# array([-3.2409,  6.1087,  2.2531, -6.0686, -3.083 ,  3.2484, -0.5443,
#         1.0945, -3.3109,  0.0597,  0.3049,  2.4366,  2.0079])

# %%
print("Mean absolute error:", round(mae(preds, y_test), 4), "\n"
      "Root mean squared error:", round(rmse(preds, y_test), 4))
# Out:
# Mean absolute error: 2.6439
# Root mean squared error: 3.8647

# %%
plt.xlabel("Predicted value")
plt.ylabel("Target")
plt.title("Predicted value vs. target,\n neural network regression")
plt.xlim([0, 51])
plt.ylim([0, 51])
plt.scatter(preds, y_test)
plt.plot([0, 51], [0, 51]);
# plt.savefig(GRAPHS_IMG_FILEPATH + "07_neural_network_regression_preds_vs_target.png");

# %%
np.round(np.mean(np.array(np.abs(preds - y_test))), 4)
# Out:
# 2.6439

# %%
np.round(np.mean(np.array(np.power(preds - y_test, 2))), 4)
# Out:
# 14.9362

# %% [markdown]
# ## Theoretical relationship between most important feature and target

# %%
NUM = 40
a = np.repeat(X_test[:,:-1].mean(axis=0, keepdims=True), NUM, axis=0)
b = np.linspace(-1.5, 3.5, NUM).reshape(NUM, 1)
test_feature = np.concatenate([a, b], axis=1)
preds_test = predict(test_feature, weights)[:, 0]

# %%
plt.scatter(X_test[:, 12], preds)
plt.plot(np.array(test_feature[:, -1]), preds_test, linewidth=2, c='orange')
plt.ylim([6, 51])
plt.xlabel("Most important feature (normalized)")
plt.ylabel("Target/Predictions")
plt.title("Most important feature vs. target and predictions,\n neural network regression");
# plt.savefig(GRAPHS_IMG_FILEPATH + "08_neural_network_regression_impt_feat_vs_preds.png")
